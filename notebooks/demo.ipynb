# %% [markdown]
# # Log File Parsing Demonstration
#
# This Jupyter Notebook shows how to parse a log file to extract key fields such as IP address, timestamp, request method, URL, status code, response size, and query parameters.
#
# Note: This notebook is for demonstration part of the parsing part only. The full project runs in a `ETL.py` file.

# %% [markdown]
# # Step 1: Read the file
#
#
#     I checked the log file in Notepad and it had 1,129 lines.
#     When we read the file, it should have the same number of lines.

# %%
path = r"DATA/nginx_logs - Copy.txt"
with open(path, "r") as f:
    logs = f.readlines()
    logs = [log.strip() for log in logs] # This is for triming and getting rid of those '\n's.
    print("number of logs:\t",len(logs))
# Out:
# number of logs:	 1129

# %% [markdown]
# # Step 2: Parse it
#
#     Now we have a list of the nginx logs.lets take a look at it.

# %%
logs[:9]
# Out:
# ['74.240.191.221 - - [25/Jun/2024:00:06:22 +0000] "DELETE /index.html?product_id=585&user_id=218 HTTP/1.1" 200 1974',
#  '15.89.35.67 - - [24/Jun/2024:04:43:22 +0000] "PUT /index.html?session_id=def456&session_id=mno345&user_id=709 HTTP/1.1" 301 4349',
#  '158.20.204.46 - - [21/Jun/2024:14:54:22 +0000] "GET /contact.html?session_id=def456 HTTP/1.1" 200 4060',
#  '158.20.204.46 - - [21/Jun/2024:14:54:22 +0000] "GET /contact.html?session_id=def456 HTTP/1.1" 200 4060',
#  '238.189.173.32 - - [21/Jun/2024:21:33:22 +0000] "GET /signup?session_id=abc123&session_id=ghi789 HTTP/1.1" 500 2661',
#  '190.111.164.7 - - [26/Jun/2024:09:03:22 +0000] "GET /products.html?session_id=mno345&user_id=483 HTTP/1.1" 302 629',
#  '196.224.137.79 - - [22/Jun/2024:09:44:22 +0000] "POST /login?session_id=ghi789 HTTP/1.1" 200 2661',
#  '248.187.87.40 - - [21/Jun/2024:16:46:22 +0000] "DELETE /signup?session_id=ghi789 HTTP/1.1" 200 734',
#  '158.20.204.46 - - [24/Jun/2024:06:15:22 +0000] "DELETE /products.html?session_id=mno345&product_id=16 HTTP/1.1" 302 3432']

# %% [markdown]
# - For ease of use and clarity of my explanation, I will demonstrate the process on an element of this list and then apply it to the entire dataset.

# %%
log = logs[0]
log
# Out:
# '74.240.191.221 - - [25/Jun/2024:00:06:22 +0000] "DELETE /index.html?product_id=585&user_id=218 HTTP/1.1" 200 1974'

# %%
from datetime import datetime

# %%
def parse_logfile(logfile):
    """
    Parses a log entry, extracts the necessary fields, and returns a dictionary.
    
    Parameters:
    logfile (str): A single log entry string.
    
    Returns:
    dict: A dictionary containing the extracted fields.
    """
    o = {}
    
    first_split = logfile.split(" - - ") 
    ip_address = first_split[0].strip()
    
    second_split = first_split[1].replace("[","").split("]")
    timestamp = second_split[0].strip()
    
    http_req, url, _, status_code, response_size = second_split[1].replace("\"","").split()
    query_param = url.split("?")[1] if "?" in url else ""
        
    o["IP_Address"] = ip_address
    o["Timestamp"] = datetime.strptime(timestamp,"%d/%b/%Y:%H:%M:%S %z")
    o["Request_Method"] = http_req   
    o["URL"] = url
    o["Status_Code"] = int(status_code)
    o["Query_Parameters"] = query_param
    
    # Some of resopnse sizes are "-" and not int type
    # o["Response_Size"] = response_size if type(response_size) == int else 0
    o["Response_Size"] = 0 if response_size == "-" else response_size

    return o

# %% [markdown]
# - Here is the output of the function:

# %%
output = parse_logfile(log)
output
# Out:
# {'IP_Address': '74.240.191.221',
#  'Timestamp': datetime.datetime(2024, 6, 25, 0, 6, 22, tzinfo=datetime.timezone.utc),
#  'Request_Method': 'DELETE',
#  'URL': '/index.html?product_id=585&user_id=218',
#  'Status_Code': 200,
#  'Query_Parameters': 'product_id=585&user_id=218',
#  'Response_Size': '1974'}

# %% [markdown]
# - Now I want to do these processes for the more logs.

# %%
output = []

for log in logs:
    o = parse_logfile(log)
    output.append(o)

# %%
import pandas as pd

df = pd.DataFrame(output)
df
# Out:
#           IP_Address                 Timestamp Request_Method  \
# 0     74.240.191.221 2024-06-25 00:06:22+00:00         DELETE
# 1        15.89.35.67 2024-06-24 04:43:22+00:00            PUT
# 2      158.20.204.46 2024-06-21 14:54:22+00:00            GET
# 3      158.20.204.46 2024-06-21 14:54:22+00:00            GET
# 4     238.189.173.32 2024-06-21 21:33:22+00:00            GET
# ...              ...                       ...            ...
# 1124  147.77.212.177 2024-06-23 20:12:22+00:00           POST
# 1125   13.224.24.185 2024-06-25 22:48:22+00:00         DELETE
# 1126   35.239.32.150 2024-06-20 08:28:22+00:00           POST
# 1127    151.80.55.55 2024-06-19 20:48:22+00:00         DELETE
# 1128  255.181.37.177 2024-06-24 07:04:22+00:00            GET
#
#                                                     URL  Status_Code  \
# 0                /index.html?product_id=585&user_id=218          200
# 1     /index.html?session_id=def456&session_id=mno34...          301
# 2                       /contact.html?session_id=def456          200
# 3                       /contact.html?session_id=def456          200
# 4           /signup?session_id=abc123&session_id=ghi789          500
# ...                                                 ...          ...
# 1124                /login?product_id=15&product_id=900          500
# 1125      /services.html?product_id=6&session_id=abc123          301
# 1126                         /index.html?product_id=170          200
# 1127                            /index.html?user_id=834          301
# 1128        /products.html?product_id=267&category=home          404
#
#                                      Query_Parameters Response_Size
# 0                          product_id=585&user_id=218          1974
# 1     session_id=def456&session_id=mno345&user_id=709          4349
# 2                                   session_id=def456          4060
# 3                                   session_id=def456          4060
# 4                 session_id=abc123&session_id=ghi789          2661
# ...                                               ...           ...
# 1124                     product_id=15&product_id=900          4049
# 1125                   product_id=6&session_id=abc123          1500
# 1126                                   product_id=170          4292
# 1127                                      user_id=834          3508
# 1128                     product_id=267&category=home          1500
#
# [1129 rows x 7 columns]

# %% [markdown]
# # Step 3: Clean it
#     Now let's see if the df has any duplicates or not.

# %%
len(df[df.duplicated()])
# Out:
# 129

# %%
df[df.duplicated()]
# Out:
#            IP_Address                 Timestamp Request_Method  \
# 3       158.20.204.46 2024-06-21 14:54:22+00:00            GET
# 9       158.20.204.46 2024-06-24 06:15:22+00:00         DELETE
# 21    134.207.168.109 2024-06-20 12:18:22+00:00            PUT
# 24       57.179.44.69 2024-06-19 23:09:22+00:00            GET
# 28     127.132.184.75 2024-06-22 21:17:22+00:00         DELETE
# ...               ...                       ...            ...
# 1077             NULL 2024-06-21 22:41:22+00:00            PUT
# 1082    62.82.168.113 2024-06-20 01:14:22+00:00           POST
# 1101   224.15.134.151 2024-06-23 03:22:22+00:00            PUT
# 1114   250.58.233.174 2024-06-20 12:05:22+00:00           POST
# 1118    75.108.179.75 2024-06-20 22:55:22+00:00         DELETE
#
#                                                     URL  Status_Code  \
# 3                       /contact.html?session_id=def456          200
# 9        /products.html?session_id=mno345&product_id=16          302
# 21                                /signup?category=home          200
# 24    /products.html?session_id=ghi789&product_id=78...          500
# 28                    /login?user_id=465&product_id=648          302
# ...                                                 ...          ...
# 1077                       /contact.html?product_id=398          200
# 1082       /index.html?product_id=241&session_id=def456          500
# 1101  /contact.html?user_id=784&product_id=583&produ...          200
# 1114    /login?product_id=50&user_id=345&product_id=543          302
# 1118  /index.html?product_id=454&session_id=ghi789&c...          200
#
#                                        Query_Parameters Response_Size
# 3                                     session_id=def456          4060
# 9                       session_id=mno345&product_id=16          3432
# 21                                        category=home          1500
# 24         session_id=ghi789&product_id=783&user_id=239          4292
# 28                           user_id=465&product_id=648           404
# ...                                                 ...           ...
# 1077                                     product_id=398           734
# 1082                   product_id=241&session_id=def456          3405
# 1101          user_id=784&product_id=583&product_id=798          2810
# 1114           product_id=50&user_id=345&product_id=543          2517
# 1118  product_id=454&session_id=ghi789&category=fashion          3508
#
# [129 rows x 7 columns]

# %%
df = df.drop_duplicates()
df
# Out:
#           IP_Address                 Timestamp Request_Method  \
# 0     74.240.191.221 2024-06-25 00:06:22+00:00         DELETE
# 1        15.89.35.67 2024-06-24 04:43:22+00:00            PUT
# 2      158.20.204.46 2024-06-21 14:54:22+00:00            GET
# 4     238.189.173.32 2024-06-21 21:33:22+00:00            GET
# 5      190.111.164.7 2024-06-26 09:03:22+00:00            GET
# ...              ...                       ...            ...
# 1124  147.77.212.177 2024-06-23 20:12:22+00:00           POST
# 1125   13.224.24.185 2024-06-25 22:48:22+00:00         DELETE
# 1126   35.239.32.150 2024-06-20 08:28:22+00:00           POST
# 1127    151.80.55.55 2024-06-19 20:48:22+00:00         DELETE
# 1128  255.181.37.177 2024-06-24 07:04:22+00:00            GET
#
#                                                     URL  Status_Code  \
# 0                /index.html?product_id=585&user_id=218          200
# 1     /index.html?session_id=def456&session_id=mno34...          301
# 2                       /contact.html?session_id=def456          200
# 4           /signup?session_id=abc123&session_id=ghi789          500
# 5          /products.html?session_id=mno345&user_id=483          302
# ...                                                 ...          ...
# 1124                /login?product_id=15&product_id=900          500
# 1125      /services.html?product_id=6&session_id=abc123          301
# 1126                         /index.html?product_id=170          200
# 1127                            /index.html?user_id=834          301
# 1128        /products.html?product_id=267&category=home          404
#
#                                      Query_Parameters Response_Size
# 0                          product_id=585&user_id=218          1974
# 1     session_id=def456&session_id=mno345&user_id=709          4349
# 2                                   session_id=def456          4060
# 4                 session_id=abc123&session_id=ghi789          2661
# 5                       session_id=mno345&user_id=483           629
# ...                                               ...           ...
# 1124                     product_id=15&product_id=900          4049
# 1125                   product_id=6&session_id=abc123          1500
# 1126                                   product_id=170          4292
# 1127                                      user_id=834          3508
# 1128                     product_id=267&category=home          1500
#
# [1000 rows x 7 columns]

# %% [markdown]
# - Now I save the df in a csv file just in case.

# %%
df.to_csv(r"nginx_logs.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 df.to_csv(r"nginx_logs.csv")
#
# File c:\Users\Ehsan\Desktop\DE Internship Task\env\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\Ehsan\Desktop\DE Internship Task\env\lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\Ehsan\Desktop\DE Internship Task\env\lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\Ehsan\Desktop\DE Internship Task\env\lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\Ehsan\Desktop\DE Internship Task\env\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'nginx_logs.csv'

# %%
# This was just for analyzing
df[(df['Request_Method']=="GET") & (df["Status_Code"] == 200)]
# Out:
#            IP_Address                 Timestamp Request_Method  \
# 2       158.20.204.46 2024-06-21 14:54:22+00:00            GET
# 13     147.77.212.177 2024-06-23 14:28:22+00:00            GET
# 18      167.53.66.101 2024-06-24 05:05:22+00:00            GET
# 34      153.6.128.136 2024-06-21 13:17:22+00:00            GET
# 52      86.238.237.49 2024-06-20 02:02:22+00:00            GET
# 64      190.111.164.7 2024-06-20 19:21:22+00:00            GET
# 107    238.189.173.32 2024-06-24 10:12:22+00:00            GET
# 114    160.229.223.17 2024-06-25 03:59:22+00:00            GET
# 126     93.228.77.196 2024-06-22 00:27:22+00:00            GET
# 189    63.113.225.225 2024-06-21 05:04:22+00:00            GET
# 190     226.49.186.58 2024-06-23 13:52:22+00:00            GET
# 231      153.1.47.251 2024-06-23 13:10:22+00:00            GET
# 270              NULL 2024-06-20 06:57:22+00:00            GET
# 273     158.20.204.46 2024-06-20 16:43:22+00:00            GET
# 314    224.15.134.151 2024-06-20 09:05:22+00:00            GET
# 377      153.1.47.251 2024-06-23 23:14:22+00:00            GET
# 384     153.6.128.136 2024-06-21 20:30:22+00:00            GET
# 400    74.240.191.221 2024-06-21 09:38:22+00:00            GET
# 418      151.80.55.55 2024-06-20 18:53:22+00:00            GET
# 435     72.81.114.166 2024-06-21 08:02:22+00:00            GET
# 475      77.25.133.33 2024-06-23 20:41:22+00:00            GET
# 480              NULL 2024-06-23 00:20:22+00:00            GET
# 505     93.228.77.196 2024-06-21 04:59:22+00:00            GET
# 548      153.1.47.251 2024-06-20 03:43:22+00:00            GET
# 549    15.189.100.115 2024-06-25 13:04:22+00:00            GET
# 574     20.15.123.111 2024-06-25 06:56:22+00:00            GET
# 587    95.191.225.234 2024-06-23 21:44:22+00:00            GET
# 619     190.111.164.7 2024-06-22 09:47:22+00:00            GET
# 624    74.240.191.221 2024-06-25 01:53:22+00:00            GET
# 684     8.249.233.220 2024-06-26 04:54:22+00:00            GET
# 708    101.137.132.71 2024-06-23 12:32:22+00:00            GET
# 750    127.132.184.75 2024-06-20 21:36:22+00:00            GET
# 756      153.1.47.251 2024-06-22 17:07:22+00:00            GET
# 774    255.181.37.177 2024-06-25 16:51:22+00:00            GET
# 791     244.113.20.63 2024-06-25 02:31:22+00:00            GET
# 819   134.207.168.109 2024-06-25 05:21:22+00:00            GET
# 842    147.77.212.177 2024-06-23 01:49:22+00:00            GET
# 849     240.57.228.32 2024-06-23 09:03:22+00:00            GET
# 881     20.15.123.111 2024-06-26 16:59:22+00:00            GET
# 886              NULL 2024-06-24 20:46:22+00:00            GET
# 891     90.154.68.175 2024-06-26 08:15:22+00:00            GET
# 957     72.81.114.166 2024-06-26 05:33:22+00:00            GET
# 962    101.137.132.71 2024-06-20 18:49:22+00:00            GET
# 984       15.89.35.67 2024-06-26 12:38:22+00:00            GET
# 1007    248.187.87.40 2024-06-21 23:23:22+00:00            GET
# 1057  134.207.168.109 2024-06-26 01:59:22+00:00            GET
# 1085     57.179.44.69 2024-06-25 06:59:22+00:00            GET
# 1090  134.207.168.109 2024-06-25 13:40:22+00:00            GET
# 1096    90.154.68.175 2024-06-24 14:34:22+00:00            GET
# 1103   127.132.184.75 2024-06-22 19:19:22+00:00            GET
#
#                                                     URL  Status_Code  \
# 2                       /contact.html?session_id=def456          200
# 13    /index.html?product_id=50&session_id=mno345&se...          200
# 18    /login?session_id=ghi789&user_id=806&session_i...          200
# 34                         /products.html?product_id=89          200
# 52            /faq.html?session_id=mno345&category=home          200
# 64                         /about.html?category=fashion          200
# 107                                  /login?user_id=258          200
# 114                           /contact.html?user_id=186          200
# 126                /login?session_id=jkl012&user_id=366          200
# 189                            /faq.html?product_id=948          200
# 190                            /login?session_id=ghi789          200
# 231                          /faq.html?category=fashion          200
# 270   /products.html?product_id=356&session_id=ghi78...          200
# 273                       /about.html?session_id=abc123          200
# 314                               /signup?category=toys          200
# 377           /index.html?session_id=jkl012&user_id=799          200
# 384                      /faq.html?category=electronics          200
# 400        /about.html?product_id=908&session_id=mno345          200
# 418   /about.html?session_id=def456&category=electro...          200
# 435     /services.html?category=electronics&user_id=373          200
# 475                    /products.html?session_id=jkl012          200
# 480               /contact.html?category=home&user_id=9          200
# 505   /faq.html?user_id=617&category=books&session_i...          200
# 548   /contact.html?category=electronics&product_id=...          200
# 549       /faq.html?user_id=778&user_id=654&user_id=637          200
# 574              /faq.html?category=toys&product_id=778          200
# 587                          /about.html?product_id=182          200
# 619                       /index.html?session_id=jkl012          200
# 624   /services.html?session_id=abc123&category=elec...          200
# 684   /faq.html?session_id=mno345&category=fashion&p...          200
# 708                         /faq.html?session_id=def456          200
# 750   /signup?user_id=698&session_id=abc123&category...          200
# 756                       /about.html?session_id=abc123          200
# 774              /faq.html?session_id=ghi789&user_id=92          200
# 791   /about.html?session_id=def456&user_id=363&sess...          200
# 819          /contact.html?category=fashion&user_id=582          200
# 842                     /services.html?category=fashion          200
# 849      /signup?user_id=810&user_id=861&product_id=356          200
# 881                          /index.html?product_id=467          200
# 886                               /login?product_id=943          200
# 891   /about.html?user_id=487&session_id=mno345&sess...          200
# 957                        /contact.html?product_id=606          200
# 962                             /about.html?user_id=103          200
# 984              /about.html?product_id=485&user_id=940          200
# 1007                    /contact.html?session_id=ghi789          200
# 1057          /about.html?product_id=177&product_id=682          200
# 1085                      /services.html?product_id=672          200
# 1090  /services.html?session_id=jkl012&category=book...          200
# 1096  /login?session_id=jkl012&user_id=681&session_i...          200
# 1103  /signup?session_id=mno345&user_id=997&user_id=466          200
#
#                                        Query_Parameters Response_Size
# 2                                     session_id=def456          4060
# 13    product_id=50&session_id=mno345&session_id=jkl012          3981
# 18      session_id=ghi789&user_id=806&session_id=ghi789          3414
# 34                                        product_id=89          2287
# 52                      session_id=mno345&category=home           847
# 64                                     category=fashion          2120
# 107                                         user_id=258          4349
# 114                                         user_id=186           596
# 126                       session_id=jkl012&user_id=366           734
# 189                                      product_id=948          2053
# 190                                   session_id=ghi789             0
# 231                                    category=fashion             0
# 270   product_id=356&session_id=ghi789&session_id=mn...          2287
# 273                                   session_id=abc123           322
# 314                                       category=toys             0
# 377                       session_id=jkl012&user_id=799           382
# 384                                category=electronics          1110
# 400                    product_id=908&session_id=mno345          3981
# 418   session_id=def456&category=electronics&user_id=82           279
# 435                    category=electronics&user_id=373          1974
# 475                                   session_id=jkl012           141
# 480                             category=home&user_id=9          4732
# 505        user_id=617&category=books&session_id=jkl012          1500
# 548   category=electronics&product_id=225&category=b...             0
# 549                 user_id=778&user_id=654&user_id=637          3854
# 574                        category=toys&product_id=778             0
# 587                                      product_id=182          3515
# 619                                   session_id=jkl012          2320
# 624   session_id=abc123&category=electronics&categor...           322
# 684   session_id=mno345&category=fashion&product_id=653          1110
# 708                                   session_id=def456           629
# 750   user_id=698&session_id=abc123&category=electro...          3432
# 756                                   session_id=abc123          2517
# 774                        session_id=ghi789&user_id=92          3144
# 791     session_id=def456&user_id=363&session_id=ghi789           708
# 819                        category=fashion&user_id=582          1110
# 842                                    category=fashion          2831
# 849              user_id=810&user_id=861&product_id=356             0
# 881                                      product_id=467          3981
# 886                                      product_id=943          2053
# 891     user_id=487&session_id=mno345&session_id=mno345          3515
# 957                                      product_id=606          4267
# 962                                         user_id=103          1988
# 984                          product_id=485&user_id=940           141
# 1007                                  session_id=ghi789           708
# 1057                      product_id=177&product_id=682          2598
# 1085                                     product_id=672          3378
# 1090    session_id=jkl012&category=books&product_id=458          4292
# 1096    session_id=jkl012&user_id=681&session_id=abc123          2053
# 1103          session_id=mno345&user_id=997&user_id=466          3217
